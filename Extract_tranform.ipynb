# %%
# 1. Import libraries
import pandas as pd
import random
from faker import Faker
from datetime import datetime, timedelta
import os

# 2. Setup Faker and random seed
fake = Faker()
random.seed(42)

# 3. Configuration
num_records = 50
diagnoses = ['Hypertension', 'Diabetes', 'Asthma', 'Healthy', 'Obesity', 'Heart Disease']
genders = ['Male', 'Female']
smoking_statuses = ['Smoker', 'Non-smoker']
activity_levels = ['Sedentary', 'Moderate', 'Active']
cholesterol_levels = ['Low', 'Normal', 'High']
adherence_status = ['Adherent', 'Non-adherent']

# 4. Generate unique 5-digit patient IDs
patient_ids = random.sample(range(10000, 99999), num_records)

# 5. Generate health records
records = []
for i in range(num_records):
    age = random.randint(18, 90)
    weight_kg = random.uniform(50, 120)
    height_m = random.uniform(1.5, 1.9)
    bmi = round(weight_kg / (height_m ** 2), 1)
    systolic = random.randint(90, 160)
    diastolic = random.randint(60, 100)
    bp = f"{systolic}/{diastolic}"
    visit_date = fake.date_between(start_date='-2y', end_date='today')
    readmitted = random.choices(['Yes', 'No'], weights=[0.2, 0.8])[0]

    record = {
        'patient_id': patient_ids[i],
        'name': fake.name(),
        'age': age,
        'gender': random.choice(genders),
        'diagnosis': random.choice(diagnoses),
        'blood_pressure': bp,
        'bmi': bmi,
        'smoking_status': random.choice(smoking_statuses),
        'physical_activity': random.choice(activity_levels),
        'cholesterol_level': random.choice(cholesterol_levels),
        'medication_adherence': random.choice(adherence_status),
        'hospital_stay_days': random.randint(0, 14),
        'readmitted': readmitted,
        'visit_date': visit_date
    }
    records.append(record)

# 6. Create DataFrame
df = pd.DataFrame(records)

# 7. Save DataFrame to CSV
output_dir = 'health_records'   
if not os.path.exists(output_dir):
    os.makedirs(output_dir)     
output_file = os.path.join(output_dir, 'health_records.csv')
df.to_csv(output_file, index=False)         

# 8. Preview all data
df
# Out:
#     patient_id                 name  age  gender      diagnosis  \
# 0        93810         Michael Hill   66    Male   Hypertension
# 1        24592       Lauren Salazar   30    Male  Heart Disease
# 2        13278        Shelby Harper   39    Male  Heart Disease
# 3        46048         Joshua Mejia   58  Female  Heart Disease
# 4        42098         Cindy Taylor   89    Male       Diabetes
# 5        39256      Elizabeth James   38  Female        Obesity
# 6        28289  Melissa Hopkins DDS   86    Male        Healthy
# 7        23434        Taylor Daniel   40    Male       Diabetes
# 8        98696          Brian Lopez   59    Male        Obesity
# 9        81482        Joshua Martin   26    Male         Asthma
# 10       21395           Brent Wood   57  Female   Hypertension
# 11       87397            John Pena   88    Male   Hypertension
# 12       65302      Sharon Guerrero   80  Female       Diabetes
# 13       14165     Gabrielle Miller   72  Female   Hypertension
# 14       13905         Laura Wright   72    Male   Hypertension
# 15       22280       Jeremy Rodgers   80  Female         Asthma
# 16       38657             Amy Byrd   42    Male   Hypertension
# 17       40495        Katie Winters   83    Male        Obesity
# 18       76237         Caitlin Ross   90  Female       Diabetes
# 19       88907      Wesley Chambers   76  Female       Diabetes
# 20       13478        Robert Powell   38    Male  Heart Disease
# 21       83563        Kevin Carroll   32    Male  Heart Disease
# 22       36062         Rachel Curry   80  Female   Hypertension
# 23       95181          Sharon Wise   74    Male        Obesity
# 24       81426       Melissa Glover   34    Male  Heart Disease
# 25       64987     Jeffrey Gonzalez   37    Male       Diabetes
# 26       38893             Kathy Le   38  Female         Asthma
# 27       68878    Richard Flores MD   42  Female  Heart Disease
# 28       87236         James Carter   51    Male        Healthy
# 29       46463            Evan Wang   84  Female        Obesity
# 30       10851          Paul Graves   57  Female  Heart Disease
# 31       30926       Kristen Harper   90  Female        Obesity
# 32       65392        Keith Nichols   45  Female   Hypertension
# 33       54597        Rebecca Smith   43    Male        Healthy
# 34       46421         Barbara Wood   67    Male       Diabetes
# 35       30379        Jessica Stein   33  Female        Obesity
# 36       38221       Melissa Martin   78    Male         Asthma
# 37       54118      Wayne Moore Jr.   52  Female  Heart Disease
# 38       23396           Rose Smith   70  Female        Obesity
# 39       22156       Dr. John Adams   63    Male        Healthy
# 40       59797       Tamara Morales   67    Male        Obesity
# 41       22676          Kayla Allen   72    Male        Healthy
# 42       57052       Danielle Davis   71  Female       Diabetes
# 43       55082           Jaime Soto   43    Male        Obesity
# 44       89131        Jessica Wyatt   65    Male        Obesity
# 45       44671          Joel Moreno   43  Female  Heart Disease
# 46       15695          Pamela Diaz   72  Female   Hypertension
# 47       70217       Susan Martinez   37  Female        Healthy
# 48       80284        Sandra Valdez   49  Female         Asthma
# 49       26361        Brian Aguilar   45  Female        Obesity
#
#    blood_pressure   bmi smoking_status physical_activity cholesterol_level  \
# 0          136/96  21.2         Smoker          Moderate               Low
# 1          136/70  27.1     Non-smoker            Active              High
# 2          149/84  34.2     Non-smoker         Sedentary               Low
# 3          130/73  33.5     Non-smoker         Sedentary            Normal
# 4          144/97  27.1     Non-smoker         Sedentary               Low
# 5           98/84  37.9     Non-smoker            Active               Low
# 6          133/67  31.4         Smoker            Active              High
# 7         128/100  35.9     Non-smoker         Sedentary              High
# 8          136/79  35.3         Smoker         Sedentary              High
# 9          106/68  40.4     Non-smoker         Sedentary              High
# 10         137/88  24.9         Smoker         Sedentary               Low
# 11         99/100  26.2     Non-smoker         Sedentary              High
# 12         150/75  27.0         Smoker         Sedentary              High
# 13          96/66  23.1         Smoker         Sedentary               Low
# 14          99/88  22.1         Smoker         Sedentary               Low
# 15          97/70  24.6     Non-smoker          Moderate            Normal
# 16         159/63  19.9     Non-smoker            Active              High
# 17          98/75  22.4         Smoker            Active               Low
# 18         116/80  24.7     Non-smoker          Moderate            Normal
# 19         102/64  31.4     Non-smoker         Sedentary               Low
# 20         128/99  27.4     Non-smoker            Active               Low
# 21         109/77  34.8     Non-smoker         Sedentary              High
# 22          96/65  19.5         Smoker          Moderate               Low
# 23          91/67  31.7         Smoker          Moderate              High
# 24          95/82  19.5         Smoker          Moderate              High
# 25         110/71  45.1     Non-smoker          Moderate              High
# 26          94/90  44.1     Non-smoker         Sedentary               Low
# 27          98/77  30.0     Non-smoker         Sedentary               Low
# 28         134/80  17.4         Smoker          Moderate               Low
# 29         115/83  39.0     Non-smoker            Active               Low
# 30         127/95  36.4     Non-smoker            Active              High
# 31          90/79  24.0     Non-smoker          Moderate            Normal
# 32         111/65  26.0         Smoker            Active            Normal
